# %%
import pandas as pd
import os

# %%
contexts = []

for filename in os.listdir("./context"):
    print(filename)
# Out:
# 1345136.txt
# 1345137.txt
# 1345138.txt
# 1345139.txt
# 1345140.txt
# 1345141.txt
# 1345142.txt
# 1345143.txt
# 1345144.txt
# 1345145.txt
# 1345146.txt
# 1345147.txt
# 1345148.txt
# 1345149.txt
# 1345150.txt
# 1345153.txt
# 1345154.txt
# 1345155.txt
# 1345156.txt
# 1345157.txt
# 1345158.txt
# 1345159.txt
# 1345160.txt
# 1345161.txt
# 1345169.txt
# 1345170.txt
# 1345171.txt
# 1345172.txt
# 1345173.txt
# 1345174.txt
# 1345175.txt
# 1345176.txt
# 1345177.txt
# 1345178.txt
# 1345179.txt
# 1345180.txt
# 1345181.txt
# 1345182.txt
# 1345183.txt
# 1345184.txt
# 1345185.txt
# 1345186.txt
# 1345187.txt
# 1345188.txt
# 1345189.txt
# 1345190.txt
# 1345191.txt
# 1345192.txt
# 1345193.txt
# 1345194.txt
# 1345195.txt
# 1345196.txt
# 1345197.txt
# 1345198.txt
# 1345199.txt
# 1345200.txt
# 1345201.txt
# 1345202.txt

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df
# Out:
#             file                                           question  \
# 0    1345136.txt        ใครเป็นผู้ออกตราสารหนี้ภาคเอกชน ไร้ใบตราสาร
# 1    1345195.txt             Penny Stock หุ้นเหรียญ มีลักษณะอย่างไร
# 2    1345200.txt                                  ราคาต้นงวดคืออะไร
# 3    1345179.txt               อัตราการใช้สิทธิของ NVDR คือเท่าไหร่
# 4    1345158.txt  หนังสือชี้ชวนส่วนสรุปข้อมูลสำคัญ (Fund Fact Sh...
# ..           ...                                                ...
# 405  1345160.txt  กองทุนรวมตราสารหนี้ระยะยาว (Long-Term Fixed-In...
# 406  1345146.txt      อัตราดอกเบี้ยนโยบายเปลี่ยนแปลง จะส่งผลอย่างไร
# 407  1345154.txt  การลงทุนที่เน้นลงทุนในหุ้นที่มีแนวโน้มการเติบโ...
# 408  1345160.txt           กองทุนที่ได้สิทธิประโยชน์ทางภาษี คืออะไร
# 409  1345187.txt              บัญชีเงินสดปกติ (Normal Cash) คืออะไร
#
#                                                 answer  answer_start  \
# 0    ไม่มีการรวมศูนย์อย่างตราสารภาครัฐ แต่ส่วนใหญ่ด...          7716
# 1    *\tหุ้นที่มีราคาซื้อขายต่อหน่วยต่ำ (ในสหรัฐฯ ค...          3019
# 2                               ราคาต้นทุนหรือราคาซื้อ           501
# 3                 1 : 1 (NVRD : สินทรัพย์อ้างอิง) เสมอ          1012
# 4                เอกสารที่ให้ข้อมูลที่สำคัญกับผู้ลงทุน          1116
# ..                                                 ...           ...
# 405  ลงทุนในตราสารหนี้ที่มีอายุเฉลี่ยของตราสารหนี้ถ...          5707
# 406  อัตราดอกเบี้ยต่างๆในตลาดไม่ว่าจะเป็น เงินฝาก, ...           474
# 407        การลงทุนแบบเน้นการเติบโต (Growth Investing)           391
# 408  กองทุนรวมที่ให้สิทธิประโยชน์ทางภาษีกับผู้ลงทุน...         14289
# 409  บัญชีที่จะเก็บเงินค่าซื้อหลักทรัพย์เป็นเงินสดเ...          1697
#
#      answer_end
# 0          7799
# 1          3138
# 2           522
# 3          1047
# 4          1152
# ..          ...
# 405        5959
# 406         704
# 407         433
# 408       14351
# 409        1872
#
# [410 rows x 5 columns]

# %%
test_df = pd.read_csv("test.csv")
test_df

# %%
sub_df = pd.read_csv("sample_submission.csv")
sub_df.head()
# Out:
#    id                                             answer
# 0   1  สูงสุด +30% ต่ำสุด -30% ของราคาปิดสินทรัพย์อ้า...
# 1   2                                                NaN
# 2   3  จะจ่ายเป็น รายเดือน, รายไตรมาส, ทุกครึ่งปี หรื...
# 3   4                                                NaN
# 4   5                                                NaN
